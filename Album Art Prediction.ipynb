# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Death Metal / Black Metal Album Cover Art Genre Classification

# %% [markdown]
# Import a list of band / album pairs
# The list for each respective genre was taken from the top all time list from RYM
# Split releases and compilations were skipped
# Bias away from popular bands like Cannibal Corpse, Dimmu Borgir, etc

# %% [markdown]
# ## Read in album data

# %%
bands = []
albums = []
with open('death_metal.txt', 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        band, album = line.split('\t')
        bands.append(band)
        albums.append(album)

# %%
death = pd.DataFrame({'band': bands, 'album': albums})
death
# Out:
#                band                                              album
# 0             Death                                           Symbolic
# 1             Death                                              Human
# 2             Death                          The Sound of Perseverance
# 3         Cryptopsy                                       None So Vile
# 4           Gorguts                                            Obscura
# ..              ...                                                ...
# 512       Eluveitie                                             Spirit
# 513     Incantation                                  Dirges of Elysium
# 514  Pungent Stench             For God Your Soul... For Me Your Flesh
# 515       Unleashed                                   Hammer Battalion
# 516    Esoctrilihum  The Telluric Ashes of the Ö Vrth Immemorial Gods
#
# [517 rows x 2 columns]

# %%
bands = []
albums = []
with open('black_metal.txt', 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        band, album = line.split('\t')
        bands.append(band)
        albums.append(album)

# %%
black = pd.DataFrame({'band': bands, 'album': albums})
black
# Out:
#             band                                   album
# 0         Burzum                               Filosofem
# 1     Dissection               Storm of the Light's Bane
# 2        Emperor                In the Nightside Eclipse
# 3        Emperor           Anthems to the Welkin at Dusk
# 4          Ulver      Bergtatt: Et eeventyr I 5 capitler
# ..           ...                                     ...
# 501          møl                                    Jord
# 502  Mütiilation  Remains of a Ruined, Dead, Cursed Soul
# 503    Ravencult                            Morbid Blood
# 504   Forteresse                    Crépuscule d'octobre
# 505       Watain                        Lawless Darkness
#
# [506 rows x 2 columns]

# %% [markdown]
# Within each genre, there are no duplicated album titles

# %%
death[death['album'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [band, album]
# Index: []

# %%
black[black['album'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [band, album]
# Index: []

# %% [markdown]
# Find albums that appear in both lists

# %%
death['full'] = death['band'] + ' - ' + death['album']
black['full'] = black['band'] + ' - ' + black['album']

# %%
crossover = np.intersect1d(death['full'], black['full'])
crossover
# Out:
# array(['1914 - The Blind Leading the Blind',
#        'Archgoat - Whore of Bethlehem', 'Behemoth - The Satanist',
#        'Black Curse - Endless Wound', 'Convulsing - Grievous',
#        'Esoctrilihum - Eternity of Shaog', 'Esoctrilihum - Inhüma',
#        'Esoctrilihum - The Telluric Ashes of the Ö Vrth Immemorial Gods',
#        'Infernal Coil - Within a World Forgotten', 'Mefitis - Emberdawn',
#        'Necrophobic - Darkside',
#        'Necros Christos - Triune Impurity Rites',
#        'Shade Empire - Omega Arcane',
#        'Sulphur Aeon - The Scythe of Cosmic Chaos',
#        'Tchornobog - Tchornobog', 'Teitanblood - Death',
#        'Teitanblood - The Baneful Choir',
#        'The Moaning - Blood From Stone',
#        'Thy Darkened Shade - Liber Lvcifer I: Khem Sedjet',
#        'Unanimated - Ancient God of Evil', 'Zhrine - Unortheta'],
#       dtype=object)

# %% [markdown]
# Save the albums with crossover to see what the model says later

# %%
crossover_albums = death[death['full'].isin(crossover)]
crossover_albums = crossover_albums.drop(['full'], axis=1)
crossover_albums
# Out:
#                    band                                              album
# 83             Behemoth                                       The Satanist
# 204         Necrophobic                                           Darkside
# 210          Tchornobog                                         Tchornobog
# 228          Unanimated                                Ancient God of Evil
# 234        Sulphur Aeon                         The Scythe of Cosmic Chaos
# 251         The Moaning                                   Blood From Stone
# 253        Esoctrilihum                                             Inhüma
# 256          Convulsing                                           Grievous
# 260        Esoctrilihum                                  Eternity of Shaog
# 312         Teitanblood                                              Death
# 361              Zhrine                                          Unortheta
# 366  Thy Darkened Shade                       Liber Lvcifer I: Khem Sedjet
# 372         Black Curse                                      Endless Wound
# 402        Shade Empire                                       Omega Arcane
# 421         Teitanblood                                  The Baneful Choir
# 422            Archgoat                                 Whore of Bethlehem
# 439     Necros Christos                              Triune Impurity Rites
# 466                1914                        The Blind Leading the Blind
# 486             Mefitis                                          Emberdawn
# 505       Infernal Coil                           Within a World Forgotten
# 516        Esoctrilihum  The Telluric Ashes of the Ö Vrth Immemorial Gods

# %%
death = death[~death['full'].isin(crossover)]
death = death.drop(['full'], axis=1)
black = black[~black['full'].isin(crossover)]
black = black.drop(['full'], axis=1)

# %%
death
# Out:
#                band                                              album
# 0             Death                                           Symbolic
# 1             Death                                              Human
# 2             Death                          The Sound of Perseverance
# 3         Cryptopsy                                       None So Vile
# 4           Gorguts                                            Obscura
# ..              ...                                                ...
# 511    Infernal War  Redesekration: The Gospel of Hatred and Apothe...
# 512       Eluveitie                                             Spirit
# 513     Incantation                                  Dirges of Elysium
# 514  Pungent Stench             For God Your Soul... For Me Your Flesh
# 515       Unleashed                                   Hammer Battalion
#
# [496 rows x 2 columns]

# %%
black
# Out:
#             band                                   album
# 0         Burzum                               Filosofem
# 1     Dissection               Storm of the Light's Bane
# 2        Emperor                In the Nightside Eclipse
# 3        Emperor           Anthems to the Welkin at Dusk
# 4          Ulver      Bergtatt: Et eeventyr I 5 capitler
# ..           ...                                     ...
# 501          møl                                    Jord
# 502  Mütiilation  Remains of a Ruined, Dead, Cursed Soul
# 503    Ravencult                            Morbid Blood
# 504   Forteresse                    Crépuscule d'octobre
# 505       Watain                        Lawless Darkness
#
# [485 rows x 2 columns]

# %% [markdown]
# We have about the same number of death metal and black metal examples (500)

# %% [markdown]
# ## EDA

# %%
death.groupby('band').size().sort_values(ascending=False).nlargest(10)
# Out:
# band
# Napalm Death        9
# Bolt Thrower        8
# Insomnium           8
# Septicflesh         8
# Dark Tranquility    8
# Vader               7
# Death               7
# Immolation          6
# Morbid Angel        6
# Nile                5
# dtype: int64

# %%
black.groupby('band').size().sort_values(ascending=False).nlargest(10)
# Out:
# band
# Enslaved            9
# Blut aus Nord       7
# Inquisition         6
# Drudkh              6
# Paysage d'Hiver     6
# Rotting Christ      6
# Summoning           6
# Deathspell Omega    5
# Anaal Nathrakh      5
# Lunar Aurora        5
# dtype: int64

# %% [markdown]
# Group albums by band for easier downloading

# %%
death_grouped = death.groupby('band')['album'].apply(list).reset_index(name='albums')
death_grouped
# Out:
#                    band                                   albums
# 0            !T.O.O.H.!  [Pod vládou bice, Order and Punishment]
# 1            7 H.Target                   [Fast-Slow Demolition]
# 2    A Canorous Quintet            [Silence of the World Beyond]
# 3               Abyssal                        [Antikatastaseis]
# 4            Ad Nauseam      [Nihil quam vacuitas ordinatum est]
# ..                  ...                                      ...
# 257            Vomitory       [Revelation Nausea, Blood Rapture]
# 258                Vuvr                             [Pilgrimage]
# 259           Whispered            [Metsutan: Songs of the Void]
# 260           Wintersun                              [Wintersun]
# 261              Wormed                              [Exodromos]
#
# [262 rows x 2 columns]

# %%
black_grouped = black.groupby('band')['album'].apply(list).reset_index(name='albums')
black_grouped
# Out:
#                     band                                             albums
# 0      A Forest of Stars  [Grave Mounds and Grave Mistakes, A Shadowplay...
# 1                Abigail                               [Intercourse & Lust]
# 2                 Abigor  [Nachthymnen (From the Twilight Kingdom), Verw...
# 3                   Absu                 [Tara, Abzu, The Sun of tiphareth]
# 4           Abyssic Hate                                [Suicidal Emotions]
# ..                   ...                                                ...
# 250              Àrsaidh                                            [Roots]
# 251   Батюшка [Batushka]       [Литургия (Litourgiya), Панихида (Panihida)]
# 252        Крода [Kroda]  [До небокраю життя..., Schwarzpfad, Поплач мен...
# 253  Лютомысл [Lutomysl]                                     [De Profundis]
# 254       מזמור [Mizmor]                                      [Cairn, Yodh]
#
# [255 rows x 2 columns]

# %% [markdown]
# ## Metal Archives scraping

# %% [markdown]
# Download album art from Metal Archives using the metallum library: https://github.com/lcharlick/python-metallum/blob/master/metallum.py

# %%
import metallum

# %%
def get_cover_urls(df):
    urls = []
    not_found = []
    for _, row in df.iterrows():
        band = row['band']
        album = row['album']
        search = metallum.album_search(album, band=band, strict=False)
        if not search:
            not_found.append((band, album))
            continue
        result = search[0].get()
        url = result.cover
        urls.append((band, album, url))
    return urls, not_found

# %%
death_urls, death_nf = get_cover_urls(death)

# %%
death_nf
# Out:
# [('Dismember', 'Like an Ever Flowing Stream'),
#  ('Atheist', 'Piece of Jtime'),
#  ('Dark Tranquility', 'The Gallery'),
#  ('Dark Tranquility', 'Damage Done'),
#  ('Dismember', 'Indecent & Obscene'),
#  ('!T.O.O.H.!', 'Pod vládou bice'),
#  ('Dark Tranquility', 'Fiction'),
#  ('Dark Tranquility', 'Character'),
#  ('Extol', 'Udneceived'),
#  ('!T.O.O.H.!', 'Order and Punishment'),
#  ('Deceased...', 'As the Weird Travel On'),
#  ('Anata', "The Condustor's Departure"),
#  ('Necophagist', 'Onset of Putrefaction'),
#  ('Atrocity', 'Longing for Death'),
#  ('Dark Tranquility', 'Projector'),
#  ('Deceased...', 'Ghostly White'),
#  ('Deceased...', 'Fearless Undead Machines'),
#  ('Phrenelith', 'Desolate Landscape'),
#  ('Deceased...', 'Surreal Overdose'),
#  ('Necophagist', 'Epitaph'),
#  ('Dark Tranquility', "The Mind's I"),
#  ('Dark Tranquility', 'Haven'),
#  ('Séance', 'Fornever Laid To Rest'),
#  ('Dark Tranquility', 'Atoma'),
#  ('Dark Throne', 'Soulside Journey'),
#  ('Beyond Creation', 'Fatal Power of Death'),
#  ('Adversarial', 'D.E.N.A.T.B.K.O.N.'),
#  ('Grave', 'Endless Processsion of Souls'),
#  ('Deceased...', 'The Blueprints for Madness')]

# %%
import requests
import shutil

def download_cover(url, folder, img_name):
    headers = {
        'User-Agent': 'My User Agent 1.0',
        'From': 'email@domain.com'
    }
    
    response = requests.get(url, headers=headers, stream=True)
    filename = f'data/{folder}/{img_name}.jpg'
    with open(filename, 'wb') as out:
        shutil.copyfileobj(response.raw, out)
    del response

# %%
death.assign(url='')
for row in death_urls:
    band, album, url = row
    death.loc[(death['band'] == band) & (death['album'] == album), 'url'] = url

# %%
death.to_csv('death_urls.csv')

# %% [markdown]
# The URLs for the above albums were fixed manually in the CSV. For the most part, these were caused by typing/spelling errors, or punctuation that affected the search

# %%
death = pd.read_csv('death_urls.csv', index_col=0)
death
# Out:
#                band                                              album  \
# 0             Death                                           Symbolic
# 1             Death                                              Human
# 2             Death                          The Sound of Perseverance
# 3         Cryptopsy                                       None So Vile
# 4           Gorguts                                            Obscura
# ..              ...                                                ...
# 511    Infernal War  Redesekration: The Gospel of Hatred and Apothe...
# 512       Eluveitie                                             Spirit
# 513     Incantation                                  Dirges of Elysium
# 514  Pungent Stench             For God Your Soul... For Me Your Flesh
# 515       Unleashed                                   Hammer Battalion
#
#                                                    url
# 0    https://www.metal-archives.com/images/6/1/6/61...
# 1    https://www.metal-archives.com/images/6/0/6/60...
# 2    https://www.metal-archives.com/images/6/1/8/61...
# 3    https://www.metal-archives.com/images/1/9/9/19...
# 4    https://www.metal-archives.com/images/3/0/0/9/...
# ..                                                 ...
# 511  https://www.metal-archives.com/images/1/4/9/9/...
# 512  https://www.metal-archives.com/images/1/0/5/4/...
# 513  https://www.metal-archives.com/images/4/0/9/5/...
# 514  https://www.metal-archives.com/images/1/0/8/8/...
# 515  https://www.metal-archives.com/images/1/8/9/1/...
#
# [496 rows x 3 columns]

# %%
for i, row in death.iterrows():
    band = row['band']
    url = row['url']
    img = f'{band}_{i}'
    download_cover(url, 'death', img)

# %%
urls = []
not_found = []

for i in range(len(black_grouped)):
    row = black_grouped.iloc[i]
    band = row['band']
    albums = row['albums']
    search = metallum.band_search(band)
    if not search:
        not_found.append((band, ''))
        continue
    band = search[0].get()
    for album in albums:
        alb_search = band.albums.search(title=album)
        if not alb_search:
            not_found.append((band, album))
            continue
        urls.append((band, album, alb_search[0].cover))

# %%
urls
# Out:
# [(<Band: A Forest of Stars>,
#   'Grave Mounds and Grave Mistakes',
#   'https://www.metal-archives.com/images/7/2/5/9/725974.jpg'),
#  (<Band: A Forest of Stars>,
#   'A Shadowplay for Yesterdays',
#   'https://www.metal-archives.com/images/3/4/1/7/341704.jpg'),
#  (<Band: Abigor>,
#   'Nachthymnen (From the Twilight Kingdom)',
#   'https://www.metal-archives.com/images/3/2/3/5/3235.jpg'),
#  (<Band: Abigor>,
#   'Verwüstung / Invoke the Dark Age',
#   'https://www.metal-archives.com/images/3/2/3/3/3233.jpg'),
#  (<Band: Abigor>,
#   'Fractal Possession',
#   'https://www.metal-archives.com/images/1/4/7/2/147277.jpg'),
#  (<Band: Abyssic Hate>,
#   'Suicidal Emotions',
#   'https://www.metal-archives.com/images/8/1/2/9/812964.jpg'),
#  (<Band: Aeternus>,
#   'Beyond the Wandering Moon',
#   'https://www.metal-archives.com/images/2/4/0/3/2403.jpg'),
#  (<Band: Agalloch>,
#   'Pale Folklore',
#   'https://www.metal-archives.com/images/1/1/5/0/1150.jpg'),
#  (<Band: Agalloch>,
#   'Marrow of the Spirit',
#   'https://www.metal-archives.com/images/2/8/5/3/285342.jpg'),
#  (<Band: Akhlys>,
#   'Melinoë',
#   'https://www.metal-archives.com/images/8/8/1/8/881878.jpg'),
#  (<Band: Akhlys>,
#   'The Dreaming I',
#   'https://www.metal-archives.com/images/5/0/5/9/505997.jpg'),
#  (<Band: Alcest>,
#   "Souvenirs d'un autre monde",
#   'https://www.metal-archives.com/images/4/1/6/5/416569.jpg'),
#  (<Band: Alcest>,
#   'Écailles de lune',
#   'https://www.metal-archives.com/images/5/0/8/4/508462.jpg'),
#  (<Band: Alcest>,
#   'Kodama',
#   'https://www.metal-archives.com/images/5/9/4/3/594384.jpg'),
#  (<Band: Alcest>,
#   'Spiritual Instinct',
#   'https://www.metal-archives.com/images/7/9/3/5/793568.jpg'),
#  (<Band: Alghazanth>,
#   'Wreath of Thevetat',
#   'https://www.metal-archives.com/images/1/8/3/3/183377.jpg'),
#  (<Band: Altar of Plagues>,
#   'White Tomb',
#   'https://www.metal-archives.com/images/2/2/5/0/225046.jpg'),
#  (<Band: Altar of Plagues>,
#   'Mammal',
#   'https://www.metal-archives.com/images/2/9/9/8/299885.jpg'),
#  (<Band: Anaal Nathrakh>,
#   'In the Constellation of the Black Widow',
#   'https://www.metal-archives.com/images/2/3/4/2/234206.jpg'),
#  (<Band: Anaal Nathrakh>,
#   'The Codex Necro',
#   'https://www.metal-archives.com/images/3/8/0/0/3800.jpg'),
#  (<Band: Anaal Nathrakh>,
#   'Eschaton',
#   'https://www.metal-archives.com/images/1/3/0/5/130591.jpg'),
#  (<Band: Anaal Nathrakh>,
#   'Vanitas',
#   'https://www.metal-archives.com/images/3/5/1/3/351377.jpg'),
#  (<Band: Andavald>,
#   'Undir Skyggðarhaldi',
#   'https://www.metal-archives.com/images/7/8/1/0/781013.jpg'),
#  (<Band: Angantyr>,
#   'Hævn',
#   'https://www.metal-archives.com/images/1/4/8/1/148128.jpg'),
#  (<Band: Antaeus>,
#   'Blood Libels',
#   'https://www.metal-archives.com/images/1/2/6/4/126448.jpg'),
#  (<Band: Antestor>,
#   'The Forsaken',
#   'https://www.metal-archives.com/images/5/8/4/8/58483.jpg'),
#  (<Band: Aosoth>,
#   'V: The Inside Scriptures',
#   'https://www.metal-archives.com/images/6/7/1/8/671833.jpg'),
#  (<Band: Aquilus>,
#   'Griseus',
#   'https://www.metal-archives.com/images/4/8/6/2/486293.jpg'),
#  (<Band: Arckanum>,
#   'Kostogher',
#   'https://www.metal-archives.com/images/6/9/9/8/6998.jpg'),
#  (<Band: Arckanum>,
#   'Fran Marder',
#   'https://www.metal-archives.com/images/6/8/7/8/6878.jpg'),
#  (<Band: Arckanum>,
#   'ÞÞÞÞÞÞÞÞÞÞÞ',
#   'https://www.metal-archives.com/images/2/3/3/6/233698.jpg'),
#  (<Band: Arckanum>,
#   'Kampen',
#   'https://www.metal-archives.com/images/8/7/2/1/8721.jpg'),
#  (<Band: Arcturus>,
#   'Aspera Hiems Symfonia',
#   'https://www.metal-archives.com/images/2/0/1/6/2016.jpg'),
#  (<Band: Armagedda>,
#   'Only True Believers',
#   'https://www.metal-archives.com/images/3/2/3/5/32356.jpg'),
#  (<Band: Arnaut Pavle>,
#   'Arnaut Pavle',
#   'https://www.metal-archives.com/images/3/6/7/7/367771.jpg'),
#  (<Band: Ash Borer>,
#   'Ash Borer',
#   'https://www.metal-archives.com/images/3/0/1/2/301249.jpg'),
#  (<Band: Axis of Advance>,
#   'Strike',
#   'https://www.metal-archives.com/images/7/6/6/6/7666.jpg'),
#  (<Band: Bathory>,
#   'Blood Fire Death',
#   'https://www.metal-archives.com/images/7/5/8/758.jpg'),
#  (<Band: Bathory>,
#   'Under the Sign of the Black Mark',
#   'https://www.metal-archives.com/images/7/5/7/757.jpg'),
#  (<Band: Bathory>,
#   'Bathory',
#   'https://www.metal-archives.com/images/7/5/4/754.jpg'),
#  (<Band: Beherit>,
#   'Drawing Down the Moon',
#   'https://www.metal-archives.com/images/1/2/9/7/1297.jpg'),
#  (<Band: Behexen>,
#   'By the Blessing of Satan',
#   'https://www.metal-archives.com/images/3/7/0/4/37040.jpg'),
#  (<Band: Bekëth Nexëhmü>,
#   'De svarta riterna',
#   'https://www.metal-archives.com/images/3/9/9/9/399914.jpg'),
#  (<Band: Belenos>,
#   'Spicilège',
#   'https://www.metal-archives.com/images/7/3/7/5/7375.jpg'),
#  (<Band: Belenos>,
#   'Errances oniriques',
#   'https://www.metal-archives.com/images/7/3/7/6/7376.jpg'),
#  (<Band: Bethlehem>,
#   'Dictius te necare',
#   'https://www.metal-archives.com/images/3/0/3/2/3032.jpg'),
#  (<Band: Bethlehem>,
#   'Sardonischer Untergang im Zeichen irreligiöser Darbietung',
#   'https://www.metal-archives.com/images/3/0/3/3/3033.jpg'),
#  (<Band: Bethlehem>,
#   'Dark Metal',
#   'https://www.metal-archives.com/images/2/3/4/5/234520.jpg'),
#  (<Band: Blasphemy>,
#   'Gods of War',
#   'https://www.metal-archives.com/images/3/1/4/0/3140.jpg'),
#  (<Band: Blaze of Perdition>,
#   'Conscious Darkness',
#   'https://www.metal-archives.com/images/6/5/9/5/659552.jpg'),
#  (<Band: Blut aus Nord>,
#   'Memoria Vetusta II: Dialogue With the Stars',
#   'https://www.metal-archives.com/images/2/2/3/7/223730.jpg'),
#  (<Band: Blut aus Nord>,
#   'Memoria Vetusta I: Fathers of the Icy Age',
#   'https://www.metal-archives.com/images/9/7/7/6/9776.jpg'),
#  (<Band: Blut aus Nord>,
#   'The Work Which Transforms God',
#   'https://www.metal-archives.com/images/2/1/2/7/21279.jpg'),
#  (<Band: Blut aus Nord>,
#   'Ultima Thulée',
#   'https://www.metal-archives.com/images/9/7/7/5/9775.jpg'),
#  (<Band: Blut aus Nord>,
#   'Hallucinogen',
#   'https://www.metal-archives.com/images/7/9/1/0/791049.jpg'),
#  (<Band: Blut aus Nord>,
#   '777 - Cosmosophy',
#   'https://www.metal-archives.com/images/3/4/5/4/345405.jpg'),
#  (<Band: Blut aus Nord>,
#   '777 - The Desanctification',
#   'https://www.metal-archives.com/images/3/1/5/5/315556.jpg'),
#  (<Band: Borknagar>,
#   'Borknagar',
#   'https://www.metal-archives.com/images/1/8/8/4/1884.jpg'),
#  (<Band: Borknagar>,
#   'The Olden Domain',
#   'https://www.metal-archives.com/images/1/8/8/3/1883.jpg'),
#  (<Band: Burzum>,
#   'Filosofem',
#   'https://www.metal-archives.com/images/3/8/2/382.jpg'),
#  (<Band: Burzum>,
#   'Hvis lyset tar oss',
#   'https://www.metal-archives.com/images/4/1/3/0/413048.jpg'),
#  (<Band: Burzum>,
#   'Det som engang var',
#   'https://www.metal-archives.com/images/3/7/8/378.jpg'),
#  (<Band: Burzum>,
#   'Burzum',
#   'https://www.metal-archives.com/images/9/2/5/7/92577.jpg'),
#  (<Band: Caladan Brood>,
#   'Echoes of Battle',
#   'https://www.metal-archives.com/images/3/6/7/3/367365.jpg'),
#  (<Band: ColdWorld>,
#   'Melancholie²',
#   'https://www.metal-archives.com/images/1/8/9/5/189521.jpg'),
#  (<Band: Conqueror>,
#   'War Cult Supremacy',
#   'https://www.metal-archives.com/images/8/6/6/1/8661.jpg'),
#  (<Band: Cor Scorpii>,
#   'Monument',
#   'https://www.metal-archives.com/images/1/8/9/4/189445.jpg'),
#  (<Band: Cradle of Filth>,
#   'Cruelty and the Beast',
#   'https://www.metal-archives.com/images/6/9/69.jpg'),
#  (<Band: Cradle of Filth>,
#   'Midian',
#   'https://www.metal-archives.com/images/7/1/71.jpg'),
#  (<Band: Craft>,
#   'Fuck the Universe',
#   'https://www.metal-archives.com/images/9/4/6/8/94689.jpg'),
#  (<Band: Craft>,
#   'Total Soul Rape',
#   'https://www.metal-archives.com/images/3/2/7/7/3277.jpg'),
#  (<Band: Cult of Fire>,
#   'मृत्यु का तापसी अनुध्यान',
#   'https://www.metal-archives.com/images/3/9/0/7/390747.jpg'),
#  (<Band: Cult of Fire>,
#   'Triumvirát',
#   'https://www.metal-archives.com/images/3/4/5/6/345681.jpg'),
#  (<Band: Dark Tribe>,
#   'In Jeraspunta - Die Rückkehr der tollwütigen Bestie',
#   'https://www.metal-archives.com/images/6/4/4/6/64464.jpg'),
#  (<Band: Darkestrah>,
#   'Epos',
#   'https://www.metal-archives.com/images/1/3/8/9/138961.jpg'),
#  (<Band: Darkspace>,
#   'Dark Space III',
#   'https://www.metal-archives.com/images/1/9/2/2/192246.jpg'),
#  (<Band: Darkspace>,
#   'Dark Space III I',
#   'https://www.metal-archives.com/images/4/5/3/0/453051.jpg'),
#  (<Band: Darkspace>,
#   'Dark Space I',
#   'https://www.metal-archives.com/images/3/0/2/3/30235.jpg'),
#  (<Band: Darkspace>,
#   'Dark Space II',
#   'https://www.metal-archives.com/images/9/8/5/6/98560.jpg'),
#  (<Band: Darkthrone>,
#   'A Blaze in the Northern Sky',
#   'https://www.metal-archives.com/images/6/1/2/612.jpg'),
#  (<Band: Darkthrone>,
#   'Transilvanian Hunger',
#   'https://www.metal-archives.com/images/6/2/4/624.jpg'),
#  (<Band: Darkthrone>,
#   'Under a Funeral Moon',
#   'https://www.metal-archives.com/images/6/2/8/628.jpg'),
#  (<Band: Darkthrone>,
#   'Panzerfaust',
#   'https://www.metal-archives.com/images/6/5/3/653.jpg'),
#  (<Band: Daudadagr>,
#   'Nordanland',
#   'https://www.metal-archives.com/images/4/7/9/0/479026.jpg'),
#  (<Band: Deafheaven>,
#   'Sunbather',
#   'https://www.metal-archives.com/images/3/7/2/3/372328.jpg'),
#  (<Band: Deafheaven>,
#   'New Bermuda',
#   'https://www.metal-archives.com/images/5/2/4/8/524809.jpg'),
#  (<Band: Deafheaven>,
#   'Ordinary Corrupt Human Love',
#   'https://www.metal-archives.com/images/7/0/9/3/709391.jpg'),
#  (<Band: Deathspell Omega>,
#   'Paracletus',
#   'https://www.metal-archives.com/images/2/8/5/0/285013.jpg'),
#  (<Band: Deathspell Omega>,
#   'Fas - Ite, maledicti, in ignem aeternum',
#   'https://www.metal-archives.com/images/1/5/7/3/157375.png'),
#  (<Band: Deathspell Omega>,
#   'Si Monvmentvm reqvires, circvmspice',
#   'https://www.metal-archives.com/images/3/9/1/0/39107.jpg'),
#  (<Band: Deathspell Omega>,
#   'The Synarchy of Molten Bones',
#   'https://www.metal-archives.com/images/6/0/7/8/607837.jpg'),
#  (<Band: Deathspell Omega>,
#   'The Furnaces of Palingenesia',
#   'https://www.metal-archives.com/images/7/7/5/1/775127.jpg'),
#  (<Band: Demoncy>,
#   'Joined in Darkness',
#   'https://www.metal-archives.com/images/1/9/4/6/19465.jpg'),
#  (<Band: Der Weg einer Freiheit>,
#   'Finisterre',
#   'https://www.metal-archives.com/images/6/4/9/6/649628.jpg'),
#  (<Band: Deströyer 666>,
#   'Phoenix Rising',
#   'https://www.metal-archives.com/images/1/1/6/4/1164.jpg'),
#  (<Band: Deströyer 666>,
#   'Unchain the Wolves',
#   'https://www.metal-archives.com/images/1/1/6/1/1161.jpg'),
#  (<Band: Deus Mortem>,
#   'Kosmocide',
#   'https://www.metal-archives.com/images/7/7/0/3/770395.jpg'),
#  (<Band: Diabolical Masquerade>,
#   'Nightwork',
#   'https://www.metal-archives.com/images/1/0/9/7/1097.jpg'),
#  (<Band: Diabolical Masquerade>,
#   'Ravendusk in My Heart',
#   'https://www.metal-archives.com/images/9/9/8/998.jpg'),
#  (<Band: Dimmu Borgir>,
#   'Puritanical Euphoric Misanthropia',
#   'https://www.metal-archives.com/images/3/4/4/344.jpg'),
#  (<Band: Dordeduh>,
#   'Dar de duh',
#   'https://www.metal-archives.com/images/3/4/8/6/348668.jpg'),
#  (<Band: Drautran>,
#   'Throne of the Depths',
#   'https://www.metal-archives.com/images/1/1/2/1/112163.jpg'),
#  (<Band: Drudkh>,
#   'Кров у наших криницях (Blood in Our Wells)',
#   'https://www.metal-archives.com/images/1/1/2/3/112304.jpg'),
#  (<Band: Drudkh>,
#   'Autumn Aurora',
#   'https://www.metal-archives.com/images/3/4/4/9/34494.jpg'),
#  (<Band: Drudkh>,
#   'Forgotten Legends',
#   'https://www.metal-archives.com/images/2/9/1/0/29104.jpg'),
#  (<Band: Drudkh>,
#   'Відчуженість (Estrangement)',
#   'https://www.metal-archives.com/images/1/6/7/7/167798.jpg'),
#  (<Band: Drudkh>,
#   'Microcosmos',
#   'https://www.metal-archives.com/images/2/3/5/4/235418.jpg'),
#  (<Band: Drudkh>,
#   'Лебединий шлях (The Swan Road)',
#   'https://www.metal-archives.com/images/7/1/4/4/71447.jpg'),
#  (<Band: Dødheimsgard>,
#   '666 International',
#   'https://www.metal-archives.com/images/6/2/9/9/6299.jpg'),
#  (<Band: Evilfeast>,
#   'Elegies of the Stellar Wind',
#   'https://www.metal-archives.com/images/6/7/6/7/676765.jpg'),
#  (<Band: Evilfeast>,
#   'Mysteries of the Nocturnal Forest',
#   'https://www.metal-archives.com/images/6/1/8/9/61892.jpg'),
#  (<Band: Evilfeast>,
#   'Lost Horizons of Wisdom',
#   'https://www.metal-archives.com/images/2/0/0/7/200744.jpg'),
#  (<Band: Fen>,
#   'Carrion Skies',
#   'https://www.metal-archives.com/images/4/5/2/8/452875.jpg'),
#  (<Band: Fleurety>,
#   'Min tid skal komme',
#   'https://www.metal-archives.com/images/8/1/7/3/8173.jpg'),
#  (<Band: Forefather>,
#   'Steadfast',
#   'https://www.metal-archives.com/images/1/8/6/0/186015.jpg'),
#  (<Band: Forgotten Woods>,
#   'The Curse of Mankind',
#   'https://www.metal-archives.com/images/2/8/7/4/2874.jpg'),
#  (<Band: Forteresse>,
#   'Métal noir québécois',
#   'https://www.metal-archives.com/images/1/4/0/8/140801.jpg'),
#  (<Band: Forteresse>,
#   'Thèmes pour la rébellion',
#   'https://www.metal-archives.com/images/5/7/9/5/579556.jpg'),
#  (<Band: Forteresse>,
#   "Crépuscule d'octobre",
#   'https://www.metal-archives.com/images/3/2/0/8/320891.jpg'),
#  (<Band: Gorgoroth>,
#   'Under the Sign of Hell',
#   'https://www.metal-archives.com/images/2/3/3/3/2333.jpg'),
#  (<Band: Gorgoroth>,
#   'Pentagram',
#   'https://www.metal-archives.com/images/2/3/3/0/2330.jpg'),
#  (<Band: Gorgoroth>,
#   'Antichrist',
#   'https://www.metal-archives.com/images/2/3/3/1/2331.jpg'),
#  (<Band: Grand Belial's Key>,
#   'Judeobeast Assassination',
#   'https://www.metal-archives.com/images/1/0/8/5/1085.JPG'),
#  (<Band: Grand Belial's Key>,
#   'Mocking the Philanthropist',
#   'https://www.metal-archives.com/images/1/0/8/3/1083.jpg'),
#  (<Band: Grand Belial's Key>,
#   'Kosherat',
#   'https://www.metal-archives.com/images/1/0/2/6/102696.jpg'),
#  (<Band: Gris>,
#   'Il était une forêt...',
#   'https://www.metal-archives.com/images/1/6/5/4/165412.jpg'),
#  (<Band: Gruzja>,
#   'Jeszcze nie mamy na was pomysłu',
#   'https://www.metal-archives.com/images/7/9/8/3/798346.jpg'),
#  (<Band: Hate Forest>,
#   'Purity',
#   'https://www.metal-archives.com/images/2/8/8/4/28845.jpg'),
#  (<Band: Hate Forest>,
#   'Sorrow',
#   'https://www.metal-archives.com/images/7/8/1/6/78168.jpg'),
#  (<Band: Havukruunu>,
#   'Uinuos syömein sota',
#   'https://www.metal-archives.com/images/8/6/2/3/862385.jpg'),
#  (<Band: Havukruunu>,
#   'Kelle surut soi',
#   'https://www.metal-archives.com/images/6/4/1/2/641286.jpg'),
#  (<Band: Havukruunu>,
#   'Havulinnaan',
#   'https://www.metal-archives.com/images/5/4/0/8/540856.jpg'),
#  (<Band: Hellhammer>,
#   'Satanic Rites',
#   'https://www.metal-archives.com/images/2/5/9/6/2596.jpg'),
#  (<Band: Hellripper>,
#   'Coagulating Darkness',
#   'https://www.metal-archives.com/images/6/4/0/2/640204.jpg'),
#  (<Band: Hellripper>,
#   'The Affair of the Poisons',
#   'https://www.metal-archives.com/images/8/4/2/4/842403.jpg'),
#  (<Band: Horna>,
#   'Envaatnags Eflos Solf Esgantaavne',
#   'https://www.metal-archives.com/images/6/9/4/2/69425.jpg'),
#  (<Band: Horna>,
#   'Sanojesi äärelle',
#   'https://www.metal-archives.com/images/2/1/0/5/210561.jpg'),
#  (<Band: Howls of Ebb>,
#   'Vigils of the 3rd Eye',
#   'https://www.metal-archives.com/images/4/0/2/6/402633.jpg'),
#  (<Band: I>,
#   'Between Two Worlds',
#   'https://www.metal-archives.com/images/1/3/1/6/131602.jpg'),
#  (<Band: Impaled Nazarene>,
#   'Ugra-Karma',
#   'https://www.metal-archives.com/images/1/2/8/7/1287.jpg'),
#  (<Band: Imperial Triumphant>,
#   'Vile Luxury',
#   'https://www.metal-archives.com/images/7/1/2/5/712516.jpg'),
#  (<Band: Imperium Dekadenz>,
#   'Dämmerung der Szenarien',
#   'https://www.metal-archives.com/images/1/6/0/5/160530.jpg'),
#  (<Band: Judas Iscariot>,
#   'To Embrace the Corpses Bleeding',
#   'https://www.metal-archives.com/images/5/8/1/5/581512.jpg'),
#  (<Band: Judas Iscariot>,
#   'Heaven in Flames',
#   'https://www.metal-archives.com/images/4/1/8/0/418084.jpg'),
#  (<Band: Kaatayra>,
#   'Toda história pela frente',
#   'https://www.metal-archives.com/images/8/7/3/4/873434.jpg'),
#  (<Band: Kaatayra>,
#   'Só quem viu o relâmpago à sua direita sabe',
#   'https://www.metal-archives.com/images/8/3/7/2/837293.jpg'),
#  (<Band: Kaevum>,
#   'Natur',
#   'https://www.metal-archives.com/images/3/2/9/9/329933.jpg'),
#  (<Band: Kampfar>,
#   'Mellom skogkledde aaser',
#   'https://www.metal-archives.com/images/1/4/6/4/14646.jpg'),
#  (<Band: Keep of Kalessin>,
#   'Armada',
#   'https://www.metal-archives.com/images/1/1/0/7/110717.jpg'),
#  (<Band: Kekal>,
#   '1000 Thoughts of Violence',
#   'https://www.metal-archives.com/images/1/6/8/9/16890.jpg'),
#  (<Band: Klabautamann>,
#   'Merkur',
#   'https://www.metal-archives.com/images/2/3/5/4/235488.jpg'),
#  (<Band: Kostnatění>,
#   'Hrůza zvítězí',
#   'https://www.metal-archives.com/images/7/9/5/0/795005.jpg'),
#  (<Band: Krallice>,
#   'Years Past Matter',
#   'https://www.metal-archives.com/images/3/5/0/2/350236.jpg'),
#  (<Band: Krallice>,
#   'Krallice',
#   'https://www.metal-archives.com/images/2/0/4/2/204209.jpg'),
#  (<Band: Kriegsmaschine>,
#   'Altered States of Divinity',
#   'https://www.metal-archives.com/images/8/8/1/8/88185.gif'),
#  (<Band: Kriegsmaschine>,
#   'Enemy of Man',
#   'https://www.metal-archives.com/images/4/0/1/3/401355.jpg'),
#  (<Band: Kriegsmaschine>,
#   'Apocalypticists',
#   'https://www.metal-archives.com/images/7/4/1/1/741196.jpg'),
#  (<Band: Krohm>,
#   'A World Through Dead Eyes',
#   'https://www.metal-archives.com/images/5/3/3/9/53398.jpg'),
#  (<Band: Kvist>,
#   'For kunsten maa vi evig vike',
#   'https://www.metal-archives.com/images/6/3/9/8/6398.jpg'),
#  (<Band: Lamp of Murmuur>,
#   'Heir of Ecliptical Romanticism',
#   'https://www.metal-archives.com/images/8/7/6/2/876225.jpg'),
#  (<Band: Lantlôs>,
#   '.neon',
#   'https://www.metal-archives.com/images/2/7/1/9/271951.jpg'),
#  (<Band: Lifelover>,
#   'Konkurs',
#   'https://www.metal-archives.com/images/2/0/5/7/205732.jpg'),
#  (<Band: Lifelover>,
#   'Erotik',
#   'https://www.metal-archives.com/images/1/4/1/8/141858.jpg'),
#  (<Band: Limbonic Art>,
#   'In Abhorrence Dementia',
#   'https://www.metal-archives.com/images/2/2/5/0/2250.jpg'),
#  (<Band: Limbonic Art>,
#   'Moon in the Scorpio',
#   'https://www.metal-archives.com/images/2/2/4/9/2249.jpg'),
#  (<Band: Lord Belial>,
#   'Enter the Moonlight Gate',
#   'https://www.metal-archives.com/images/3/2/5/6/3256.jpg'),
#  (<Band: Lunar Aurora>,
#   'Andacht',
#   'https://www.metal-archives.com/images/6/7/5/5/675553.jpg'),
#  (<Band: Lunar Aurora>,
#   'Mond',
#   'https://www.metal-archives.com/images/9/2/4/4/92449.jpg'),
#  (<Band: Lunar Aurora>,
#   'Elixir of Sorrow',
#   'https://www.metal-archives.com/images/4/3/2/1/43211.jpg'),
#  (<Band: Lunar Aurora>,
#   'Hoagascht',
#   'https://www.metal-archives.com/images/3/2/7/9/327976.jpg'),
#  (<Band: Lunar Aurora>,
#   'Zyklus',
#   'https://www.metal-archives.com/images/6/2/8/0/62800.jpg'),
#  (<Band: Lurker of Chalice>,
#   'Lurker of Chalice',
#   'https://www.metal-archives.com/images/8/9/2/9/89297.jpg'),
#  (<Band: Lux Occulta>,
#   'My Guardian Anger',
#   'https://www.metal-archives.com/images/9/5/3/7/9537.jpg'),
#  (<Band: Macabre Omen>,
#   'Gods of War - At War',
#   'https://www.metal-archives.com/images/4/9/2/9/492967.jpg'),
#  (<Band: Mare Cognitum>,
#   'Phobos Monolith',
#   'https://www.metal-archives.com/images/4/5/6/8/456893.jpg'),
#  (<Band: Mare Cognitum>,
#   'Luminiferous Aether',
#   'https://www.metal-archives.com/images/5/9/5/6/595617.jpg'),
#  (<Band: Master's Hammer>,
#   'Ritual',
#   'https://www.metal-archives.com/images/6/6/9/4/6694.jpg'),
#  (<Band: Master's Hammer>,
#   'Jilemnický okultista',
#   'https://www.metal-archives.com/images/6/6/9/6/6696.jpg'),
#  (<Band: Melechesh>,
#   'Emissaries',
#   'https://www.metal-archives.com/images/1/3/1/4/131481.jpg'),
#  (<Band: Melechesh>,
#   'Sphynx',
#   'https://www.metal-archives.com/images/1/9/1/6/19161.jpg'),
#  (<Band: Melechesh>,
#   'The Epigenesis',
#   'https://www.metal-archives.com/images/2/8/0/2/280288.jpg'),
#  (<Band: Melechesh>,
#   'Enki',
#   'https://www.metal-archives.com/images/5/8/5/2/585226.jpg'),
#  (<Band: Mgła>,
#   'Exercises in Futility',
#   'https://www.metal-archives.com/images/5/2/7/7/527726.jpg'),
#  (<Band: Mgła>,
#   'With Hearts Toward None',
#   'https://www.metal-archives.com/images/3/2/8/1/328134.jpg'),
#  (<Band: Mgła>,
#   'Age of Excuse',
#   'https://www.metal-archives.com/images/7/9/5/3/795325.jpg'),
#  (<Band: Mgła>,
#   'Groza',
#   'https://www.metal-archives.com/images/1/9/2/2/192294.jpg'),
#  (<Band: Midnight Odyssey>,
#   'Funerals From the Astral Sphere',
#   'https://www.metal-archives.com/images/3/1/3/4/313405.jpg'),
#  (<Band: Midnight Odyssey>,
#   'Shards of Silver Fade',
#   'https://www.metal-archives.com/images/5/0/7/4/507432.jpg'),
#  (<Band: Mistur>,
#   'Attende',
#   'https://www.metal-archives.com/images/2/4/1/2/241269.jpg'),
#  (<Band: Misþyrming>,
#   'Söngvar elds og óreiðu',
#   'https://www.metal-archives.com/images/4/8/9/9/489952.png'),
#  (<Band: Misþyrming>,
#   'Algleymi',
#   'https://www.metal-archives.com/images/7/7/5/1/775128.jpg'),
#  (<Band: Moonblood>,
#   'Blut & Krieg',
#   'https://www.metal-archives.com/images/3/2/6/4/3264.jpg'),
#  (<Band: Moonsorrow>,
#   'Verisäkeet',
#   'https://www.metal-archives.com/images/6/6/6/8/66681.jpg'),
#  (<Band: Moonsorrow>,
#   'Jumalten aika',
#   'https://www.metal-archives.com/images/5/5/7/6/557666.jpg'),
#  (<Band: Moonspell>,
#   'Under Satanæ',
#   'https://www.metal-archives.com/images/1/6/6/8/166835.jpg'),
#  (<Band: Mortuary Drape>,
#   'Secret Sudaria',
#   'https://www.metal-archives.com/images/2/0/0/3/2003.jpg'),
#  (<Band: Mortuary Drape>,
#   'All the Witches Dance',
#   'https://www.metal-archives.com/images/2/0/0/0/2000.jpg'),
#  (<Band: Murmuüre>,
#   'Murmuüre',
#   'https://www.metal-archives.com/images/2/6/9/7/269735.jpg'),
#  (<Band: Mystifier>,
#   'Göetia',
#   'https://www.metal-archives.com/images/1/7/2/9/1729.JPG'),
#  (<Band: Mörk Gryning>,
#   'Tusen år har gått...',
#   'https://www.metal-archives.com/images/6/1/1/1/6111.jpg'),
#  (<Band: Mütiilation>,
#   'Vampires of Black Imperial Blood',
#   'https://www.metal-archives.com/images/2/3/5/3/2353.jpeg'),
#  (<Band: Mütiilation>,
#   'Remains of a Ruined, Dead, Cursed Soul',
#   'https://www.metal-archives.com/images/2/3/5/5/2355.jpg'),
#  (<Band: Nagelfar>,
#   'Hünengrab im Herbst',
#   'https://www.metal-archives.com/images/1/2/3/6/12368.jpg'),
#  (<Band: Nagelfar>,
#   'Virus West',
#   'https://www.metal-archives.com/images/8/5/7/6/8576.jpg'),
#  (<Band: Necromantia>,
#   'Scarlet Evil Witching Black',
#   'https://www.metal-archives.com/images/2/4/2/2/2422.jpg'),
#  (<Band: Negative Plane>,
#   'Et in saecula saeculorum',
#   'https://www.metal-archives.com/images/1/1/2/9/112977.jpg'),
#  (<Band: Negative Plane>,
#   'Stained Glass Revelations',
#   'https://www.metal-archives.com/images/2/9/4/5/294500.jpg'),
#  (<Band: Negură Bunget>,
#   'OM',
#   'https://www.metal-archives.com/images/1/3/3/1/133198.jpg'),
#  (<Band: Negură Bunget>,
#   "'n crugu bradului",
#   'https://www.metal-archives.com/images/1/5/6/7/15670.jpg'),
#  (<Band: Negură Bunget>,
#   'Vîrstele pămîntului',
#   'https://www.metal-archives.com/images/2/6/6/8/266841.jpg'),
#  (<Band: Nehëmah>,
#   'Requiem Tenebrae',
#   'https://www.metal-archives.com/images/3/9/6/5/39658.jpg'),
#  (<Band: Nehëmah>,
#   'Light of a Dead Star',
#   'https://www.metal-archives.com/images/1/9/0/9/19091.jpg'),
#  (<Band: Nightbringer>,
#   'Ego Dominus Tuus',
#   'https://www.metal-archives.com/images/4/4/3/4/443490.jpg'),
#  (<Band: Nocte Obducta>,
#   'Nektar - Teil 2: Seen, Flüsse, Tagebücher',
#   'https://www.metal-archives.com/images/7/4/8/1/74814.jpg'),
#  (<Band: Nokturnal Mortum>,
#   'Голос сталі',
#   'https://www.metal-archives.com/images/2/5/7/4/257430.jpg'),
#  (<Band: Nokturnal Mortum>,
#   'Істина',
#   'https://www.metal-archives.com/images/6/4/8/9/648929.jpg'),
#  (<Band: Nyktalgia>,
#   'Nyktalgia',
#   'https://www.metal-archives.com/images/6/1/4/1/61417.jpg'),
#  (<Band: Nyktalgia>,
#   'Peisithanatos',
#   'https://www.metal-archives.com/images/1/9/4/4/194434.jpg'),
#  (<Band: Oathbreaker>,
#   'Rheia',
#   'https://www.metal-archives.com/images/6/0/9/0/609001.jpg'),
#  (<Band: Obsequiae>,
#   'Aria of Vernal Tombs',
#   'https://www.metal-archives.com/images/5/0/0/2/500296.jpg'),
#  (<Band: Obsequiae>,
#   'Suspended in the Brume of Eos',
#   'https://www.metal-archives.com/images/3/1/1/6/311679.jpg'),
#  (<Band: Obsequiae>,
#   'The Palms of Sorrowed Kings',
#   'https://www.metal-archives.com/images/7/9/9/0/799058.jpg'),
#  (<Band: Obtained Enslavement>,
#   'Soulblight',
#   'https://www.metal-archives.com/images/5/8/8/3/5883.jpg'),
#  (<Band: Obtained Enslavement>,
#   'Witchcraft',
#   'https://www.metal-archives.com/images/5/8/8/1/5881.jpg'),
#  (<Band: October Falls>,
#   'The Womb of Primordial Nature',
#   'https://www.metal-archives.com/images/1/9/2/7/192760.jpg'),
#  (<Band: Odraza>,
#   'Esperalem tkane',
#   'https://www.metal-archives.com/images/4/0/4/8/404839.jpg'),
#  (<Band: Odraza>,
#   'Rzeczom',
#   'https://www.metal-archives.com/images/8/4/7/1/847165.jpg'),
#  (<Band: Odz Manouk>,
#   'Odz Manouk',
#   'https://www.metal-archives.com/images/2/8/7/7/287734.jpg'),
#  (<Band: Ondskapt>,
#   'Dödens evangelium',
#   'https://www.metal-archives.com/images/7/6/9/4/76948.jpg'),
#  (<Band: Oranssi Pazuzu>,
#   'Mestarin kynsi',
#   'https://www.metal-archives.com/images/8/2/4/9/824930.jpg'),
#  (<Band: Oranssi Pazuzu>,
#   'Värähtelijä',
#   'https://www.metal-archives.com/images/5/5/0/7/550757.jpg'),
#  (<Band: Oranssi Pazuzu>,
#   'Valonielu',
#   'https://www.metal-archives.com/images/3/8/5/9/385981.jpg'),
#  (<Band: Oranssi Pazuzu>,
#   'Muukalainen puhuu',
#   'https://www.metal-archives.com/images/2/3/4/6/234600.jpg'),
#  (<Band: Paysage d'Hiver>,
#   "Paysage d'Hiver",
#   'https://www.metal-archives.com/images/2/9/6/4/29645.jpeg'),
#  (<Band: Paysage d'Hiver>,
#   'Im Wald',
#   'https://www.metal-archives.com/images/8/2/2/8/822857.jpg'),
#  (<Band: Paysage d'Hiver>,
#   'Das Tor',
#   'https://www.metal-archives.com/images/3/6/7/7/367756.jpeg'),
#  (<Band: Paysage d'Hiver>,
#   'Kristall & Isa',
#   'https://www.metal-archives.com/images/2/9/6/4/29648.jpg'),
#  (<Band: Paysage d'Hiver>,
#   'Schattengang',
#   'https://www.metal-archives.com/images/2/9/6/4/29643.jpg'),
#  (<Band: Peste Noire>,
#   'Ballade cuntre lo Anemi francor',
#   'https://www.metal-archives.com/images/2/3/1/6/231609.jpeg'),
#  (<Band: Peste Noire>,
#   "L'ordure à L'état pur",
#   'https://www.metal-archives.com/images/3/0/7/3/307396.jpg'),
#  (<Band: Plaga>,
#   'Magia gwiezdnej entropii',
#   'https://www.metal-archives.com/images/3/7/4/1/374115.png'),
#  (<Band: Primordial>,
#   "A Journey's End",
#   'https://www.metal-archives.com/images/1/5/6/3/1563.jpg'),
#  (<Band: Primordial>,
#   'Where Greater Men Have Fallen',
#   'https://www.metal-archives.com/images/4/6/0/2/460200.jpg'),
#  (<Band: Primordial>,
#   'Storm Before Calm',
#   'https://www.metal-archives.com/images/1/5/4/6/1546.jpg'),
#  (<Band: Psychonaut 4>,
#   'Neurasthenia',
#   'https://www.metal-archives.com/images/5/9/4/5/594570.jpg'),
#  (<Band: Ravencult>,
#   'Morbid Blood',
#   'https://www.metal-archives.com/images/2/9/6/5/296557.jpg'),
#  (<Band: Root>,
#   'Hell Symphony',
#   'https://www.metal-archives.com/images/3/0/7/6/3076.jpg'),
#  (<Band: Rotting Christ>,
#   'Triarchy of the Lost Lovers',
#   'https://www.metal-archives.com/images/1/1/9/9/1199.jpg'),
#  (<Band: Rotting Christ>,
#   'Non Serviam',
#   'https://www.metal-archives.com/images/1/1/9/8/1198.jpg'),
#  (<Band: Rotting Christ>,
#   'Theogonia',
#   'https://www.metal-archives.com/images/1/3/7/5/137587.JPG'),
#  (<Band: Rotting Christ>,
#   'Thy Mighty Contract',
#   'https://www.metal-archives.com/images/1/1/9/6/1196.jpg'),
#  (<Band: Rotting Christ>,
#   'Sanctus Diavolos',
#   'https://www.metal-archives.com/images/5/2/9/9/52990.jpg'),
#  (<Band: Rotting Christ>,
#   'A Dead Poem',
#   'https://www.metal-archives.com/images/1/2/0/0/1200.jpg'),
#  (<Band: S.V.E.S.T.>,
#   'Urfaust',
#   'https://www.metal-archives.com/images/3/6/4/6/36464.jpg'),
#  (<Band: Sabbat>,
#   'The Dwelling',
#   'https://www.metal-archives.com/images/1/6/9/9/1699.jpg'),
#  (<Band: Sabbat>,
#   'Karisma',
#   'https://www.metal-archives.com/images/1/7/0/2/1702.jpg'),
#  (<Band: Sabbat>,
#   'Envenom',
#   'https://www.metal-archives.com/images/1/6/9/5/1695.jpg'),
#  (<Band: Sacramentum>,
#   'Far Away From the Sun',
#   'https://www.metal-archives.com/images/2/7/1/4/2714.jpg'),
#  (<Band: Samael>,
#   'Passage',
#   'https://www.metal-archives.com/images/1/0/3/103.jpg'),
#  (<Band: Saor>,
#   'Aura',
#   'https://www.metal-archives.com/images/4/0/7/0/407027.jpg'),
#  (<Band: Saor>,
#   'Guardians',
#   'https://www.metal-archives.com/images/6/0/1/7/601760.jpg'),
#  (<Band: Sarcófago>,
#   'I.N.R.I.',
#   'https://www.metal-archives.com/images/5/8/5/2/5852.jpg'),
#  (<Band: Sarcófago>,
#   'Rotting',
#   'https://www.metal-archives.com/images/6/4/5/4/6454.jpg'),
#  (<Band: Sargeist>,
#   'Let the Devil In',
#   'https://www.metal-archives.com/images/2/8/1/3/281314.jpg'),
#  (<Band: Sargeist>,
#   'Satanic Black Devotion',
#   'https://www.metal-archives.com/images/2/5/0/7/25073.jpg'),
#  (<Band: Sargeist>,
#   'Disciple of the Heinous Path',
#   'https://www.metal-archives.com/images/9/5/6/6/95666.jpg'),
#  (<Band: Sargeist>,
#   'Unbound',
#   'https://www.metal-archives.com/images/7/3/9/3/739387.jpg'),
#  (<Band: Satan's Host>,
#   'By the Hands of the Devil',
#   'https://www.metal-archives.com/images/2/9/7/8/297898.jpg'),
#  (<Band: Satanic Warmaster>,
#   'Fimbulwinter',
#   'https://www.metal-archives.com/images/4/6/5/8/465829.jpg'),
#  (<Band: Satyricon>,
#   'Nemesis Divina',
#   'https://www.metal-archives.com/images/1/3/0/2/1302.jpg'),
#  (<Band: Satyricon>,
#   'The Shadowthrone',
#   'https://www.metal-archives.com/images/1/3/0/5/1305.jpg'),
#  (<Band: Satyricon>,
#   'Dark Medieval Times',
#   'https://www.metal-archives.com/images/1/3/0/8/1308.jpg'),
#  (<Band: Schammasch>,
#   'Contradiction',
#   'https://www.metal-archives.com/images/4/0/4/1/404193.jpg'),
#  (<Band: Schammasch>,
#   'Triangle',
#   'https://www.metal-archives.com/images/5/7/0/1/570174.jpg'),
#  (<Band: Schammasch>,
#   'Hearts of No Light',
#   'https://www.metal-archives.com/images/7/9/9/6/799643.jpg'),
#  (<Band: Sear Bliss>,
#   'The Arcane Odyssey',
#   'https://www.metal-archives.com/images/1/6/8/7/168732.jpg'),
#  (<Band: Sear Bliss>,
#   'Glory and Perdition',
#   'https://www.metal-archives.com/images/4/9/5/5/49559.jpg'),
#  (<Band: Secrets of the Moon>,
#   'Antithesis',
#   'https://www.metal-archives.com/images/1/2/0/9/120938.jpg'),
#  (<Band: Secrets of the Moon>,
#   'Privilegivm',
#   'https://www.metal-archives.com/images/2/4/3/0/243056.jpg'),
#  (<Band: Selbst>,
#   'Relatos de angustia',
#   'https://www.metal-archives.com/images/8/5/2/1/852127.png'),
#  (<Band: Serpent Column>,
#   'Mirror in Darkness',
#   'https://www.metal-archives.com/images/7/8/8/7/788731.jpeg'),
#  (<Band: Serpent Column>,
#   'Kathodos',
#   'https://www.metal-archives.com/images/8/8/4/0/884094.jpg'),
#  (<Band: Shade Empire>,
#   'Sinthetic',
#   'https://www.metal-archives.com/images/3/6/8/8/36887.jpg'),
#  (<Band: Shining>,
#   'V - Halmstad (Niklas Angående Niklas)',
#   'https://www.metal-archives.com/images/1/1/7/5/117596.jpg'),
#  (<Band: Sigh>,
#   'Hail Horror Hail',
#   'https://www.metal-archives.com/images/3/3/3/333.jpg'),
#  (<Band: Sigh>,
#   'Scorn Defeat',
#   'https://www.metal-archives.com/images/1/0/3/8/103828.jpg'),
#  (<Band: Sigh>,
#   'Infidel Art',
#   'https://www.metal-archives.com/images/3/4/5/345.jpg'),
#  (<Band: Sinmara>,
#   'Aphotic Womb',
#   'https://www.metal-archives.com/images/5/7/7/8/577879.jpg'),
#  (<Band: Skáphe>,
#   'Skáphe³',
#   'https://www.metal-archives.com/images/8/8/4/0/884097.jpg'),
#  (<Band: Solefald>,
#   'The Linear Scaffold',
#   'https://www.metal-archives.com/images/1/4/4/1/1441.jpg'),
#  (<Band: Sortsind>,
#   'Sår',
#   'https://www.metal-archives.com/images/2/6/3/3/26332.jpg'),
#  (<Band: Spectral Lore>,
#   'III',
#   'https://www.metal-archives.com/images/4/0/7/2/407298.jpg'),
#  (<Band: Spectral Wound>,
#   'Infernal Decadence',
#   'https://www.metal-archives.com/images/7/1/5/1/715108.jpg'),
#  (<Band: Spite Extreme Wing>,
#   'Vltra',
#   'https://www.metal-archives.com/images/1/9/2/7/192779.jpg'),
#  (<Band: Summoning>,
#   'Stronghold',
#   'https://www.metal-archives.com/images/1/1/4/114.jpg'),
#  (<Band: Summoning>,
#   'Let Mortal Heroes Sing Your Fame',
#   'https://www.metal-archives.com/images/1/1/5/115.jpg'),
#  (<Band: Summoning>,
#   'Oath Bound',
#   'https://www.metal-archives.com/images/1/0/8/2/108254.jpg'),
#  (<Band: Summoning>,
#   'Dol Guldur',
#   'https://www.metal-archives.com/images/8/8/88.jpg'),
#  (<Band: Summoning>,
#   'Minas Morgul',
#   'https://www.metal-archives.com/images/6/0/6/8/60680.jpg'),
#  (<Band: Summoning>,
#   'Old Mornings Dawn',
#   'https://www.metal-archives.com/images/3/7/2/4/372416.jpg'),
#  (<Band: Svartidauði>,
#   'Flesh Cathedral',
#   'https://www.metal-archives.com/images/3/5/7/4/357409.jpg'),
#  (<Band: Svartidauði>,
#   'Revelations of the Red Sword',
#   'https://www.metal-archives.com/images/7/3/9/3/739391.jpg'),
#  (<Band: Sühnopfer>,
#   'Offertoire',
#   'https://www.metal-archives.com/images/4/7/3/7/473755.jpg'),
#  (<Band: Taake>,
#   'Noregs vaapen',
#   'https://www.metal-archives.com/images/3/1/3/9/313967.jpg'),
#  (<Band: Thantifaxath>,
#   'Sacred White Noise',
#   'https://www.metal-archives.com/images/4/0/4/1/404155.jpg'),
#  (<Band: The Great Old Ones>,
#   'Cosmicism',
#   'https://www.metal-archives.com/images/7/8/8/6/788686.jpg'),
#  (<Band: The Ruins of Beverast>,
#   'Rain Upon the Impure',
#   'https://www.metal-archives.com/images/1/4/0/2/140206.jpg'),
#  (<Band: The Ruins of Beverast>,
#   'Unlock the Shrine',
#   'https://www.metal-archives.com/images/5/3/4/3/53435.jpg'),
#  (<Band: The Ruins of Beverast>,
#   'Foulest Semen of a Sheltered Elite',
#   'https://www.metal-archives.com/images/2/4/7/2/247209.jpg'),
#  (<Band: Thorns>,
#   'Thorns',
#   'https://www.metal-archives.com/images/3/0/8/0/3080.jpg'),
#  (<Band: Thurisaz>,
#   'Circadian Rhythm',
#   'https://www.metal-archives.com/images/1/4/5/5/145527.jpg'),
#  (<Band: Thurisaz>,
#   'Scent of a Dream',
#   'https://www.metal-archives.com/images/4/3/8/0/43803.jpg'),
#  (<Band: Thy Serpent>,
#   'Forests of Witchery',
#   'https://www.metal-archives.com/images/1/1/5/8/11582.jpg'),
#  (<Band: Thyrfing>,
#   'Hels Vite',
#   'https://www.metal-archives.com/images/2/0/8/3/208394.jpg'),
#  (<Band: Todtgelichter>,
#   'Angst',
#   'https://www.metal-archives.com/images/2/8/3/2/283289.jpg'),
#  (<Band: Urfaust>,
#   'Der freiwillige Bettler',
#   'https://www.metal-archives.com/images/2/9/0/5/290545.jpg'),
#  (<Band: Urfaust>,
#   'Geist ist Teufel',
#   'https://www.metal-archives.com/images/4/8/7/6/48761.jpg'),
#  (<Band: Varathron>,
#   'Walpurgisnacht',
#   'https://www.metal-archives.com/images/8/4/1/1/8411.jpg'),
#  (<Band: Varathron>,
#   'His Majesty at the Swamp',
#   'https://www.metal-archives.com/images/8/4/1/0/8410.jpg'),
#  (<Band: Varathron>,
#   'Patriarchs of Evil',
#   'https://www.metal-archives.com/images/6/9/4/1/694110.jpg'),
#  (<Band: Verdunkeln>,
#   'Einblick in den Qualenfall',
#   'https://www.metal-archives.com/images/1/5/2/2/152206.jpg'),
#  (<Band: Vinterland>,
#   'Welcome My Last Chapter',
#   'https://www.metal-archives.com/images/4/0/7/6/4076.jpg'),
#  (<Band: Volahn>,
#   "Aq'ab'al",
#   'https://www.metal-archives.com/images/4/6/7/1/467168.jpg'),
#  (<Band: Véhémence>,
#   'Par le sang versé',
#   'https://www.metal-archives.com/images/7/5/4/3/754399.jpg'),
#  (<Band: Wake>,
#   'Devouring Ruin',
#   'https://www.metal-archives.com/images/8/1/5/1/815182.jpg'),
#  (<Band: Walknut>,
#   'Graveforests and Their Shadows',
#   'https://www.metal-archives.com/images/1/5/2/4/152463.jpg'),
#  (<Band: Watain>,
#   'Casus Luciferi',
#   'https://www.metal-archives.com/images/3/3/5/0/33502.jpg'),
#  (<Band: Watain>,
#   'Lawless Darkness',
#   'https://www.metal-archives.com/images/2/7/0/4/270404.jpg'),
#  (<Band: Wayfarer>,
#   'A Romance With Violence',
#   'https://www.metal-archives.com/images/8/7/1/3/871370.jpg'),
#  (<Band: Weakling>,
#   'Dead as Dreams',
#   'https://www.metal-archives.com/images/1/3/2/0/13204.jpg'),
#  (<Band: White Ward>,
#   'Love Exchange Failure',
#   'https://www.metal-archives.com/images/7/8/8/4/788482.jpg'),
#  (<Band: Wigrid>,
#   'Hoffnungstod',
#   'https://www.metal-archives.com/images/2/3/5/5/23551.jpg'),
#  (<Band: Windir>,
#   'Arntor',
#   'https://www.metal-archives.com/images/1/3/4/6/1346.jpg'),
#  (<Band: Windir>,
#   '1184',
#   'https://www.metal-archives.com/images/1/3/4/7/1347.jpg'),
#  (<Band: Windir>,
#   'Likferd',
#   'https://www.metal-archives.com/images/1/8/7/8/18781.jpg'),
#  (<Band: Windir>,
#   'Sóknardalr',
#   'https://www.metal-archives.com/images/1/3/4/5/1345.jpg'),
#  (<Band: Winterfylleth>,
#   'The Divination of Antiquity',
#   'https://www.metal-archives.com/images/4/6/3/1/463138.jpg'),
#  (<Band: Winterfylleth>,
#   'The Threnody of Triumph',
#   'https://www.metal-archives.com/images/3/4/6/6/346688.jpg'),
#  (<Band: Wodensthrone>,
#   'Curse',
#   'https://www.metal-archives.com/images/3/3/4/1/334174.jpg'),
#  (<Band: Wolves in the Throne Room>,
#   'Two Hunters',
#   'https://www.metal-archives.com/images/5/2/9/7/529724.jpg'),
#  (<Band: Wolves in the Throne Room>,
#   'Diadem of 12 Stars',
#   'https://www.metal-archives.com/images/1/1/0/1/110195.jpg'),
#  (<Band: Wolves in the Throne Room>,
#   'Black Cascade',
#   'https://www.metal-archives.com/images/2/2/6/0/226080.jpg'),
#  (<Band: Wolves in the Throne Room>,
#   'Celestial Lineage',
#   'https://www.metal-archives.com/images/3/1/2/4/312457.jpg'),
#  (<Band: Woods of Desolation>,
#   'Torn Beyond Reason',
#   'https://www.metal-archives.com/images/2/9/0/6/290674.jpg'),
#  (<Band: Wulkanaz>,
#   'Wulkanaz',
#   'https://www.metal-archives.com/images/7/4/6/2/746269.jpg'),
#  (<Band: Wyrd>,
#   'Huldrafolk',
#   'https://www.metal-archives.com/images/8/7/8/1/8781.jpg'),
#  (<Band: Wędrujący Wiatr>,
#   'Tam, gdzie miesiąc opłakuje świt',
#   'https://www.metal-archives.com/images/3/8/0/1/380115.jpg'),
#  (<Band: Wędrujący Wiatr>,
#   'O turniach, jeziorach i nocnych szlakach',
#   'https://www.metal-archives.com/images/6/0/0/5/600546.jpg'),
#  (<Band: Xanthochroid>,
#   'Blessed He With Boils',
#   'https://www.metal-archives.com/images/3/5/8/0/358099.jpg'),
#  (<Band: Yellow Eyes>,
#   'Sick With Bloom',
#   'https://www.metal-archives.com/images/5/4/7/4/547486.jpg'),
#  (<Band: Yellow Eyes>,
#   'Immersion Trench Reverie',
#   'https://www.metal-archives.com/images/6/6/8/5/668577.jpg'),
#  (<Band: Yellow Eyes>,
#   'Rare Field Ceiling',
#   'https://www.metal-archives.com/images/7/7/0/6/770650.jpg'),
#  (<Band: Ygg>,
#   'Ygg',
#   'https://www.metal-archives.com/images/3/0/2/2/302277.jpg'),
#  (<Band: Møl>,
#   'Jord',
#   'https://www.metal-archives.com/images/6/9/4/1/694133.jpg'),
#  (<Band: Àrsaidh>,
#   'Roots',
#   'https://www.metal-archives.com/images/3/7/1/4/371416.jpg')]

# %%
not_found
# Out:
# [(<Band: Abigail>, 'Intercourse & Lust'),
#  (<Band: Absu>, 'Tara'),
#  (<Band: Absu>, 'Abzu'),
#  (<Band: Absu>, 'The Sun of tiphareth'),
#  (<Band: Aeternus>, '…And So the Night Became'),
#  (<Band: Altar of Plagues>, 'Teethed Glory and Injury'),
#  (<Band: Anaal Nathrakh>, 'Hell Is Empoty, and All the Devils Are Here'),
#  (<Band: Aosoth>, 'IV: An Arrow in Heart'),
#  (<Band: Aosoth>, 'III: Violence & Variations'),
#  (<Band: Armagedda>, 'Ond Spiritism - Djæfvulens Skalder'),
#  (<Band: Ascension>, 'Consolamentum'),
#  (<Band: Bathory>, 'The Return…'),
#  (<Band: Blasphemy>, 'Fallen Angel of Doom…'),
#  (<Band: Borknagar>, 'Empricism'),
#  ('Bölzer', ''),
#  (<Band: Chapel>, "Satan's Rock 'n' Roll"),
#  (<Band: Cobalt>, 'Gin'),
#  (<Band: Cobalt>, 'Eater of Birds'),
#  (<Band: Covenant>, 'Nexus Polaris'),
#  (<Band: Cradle of Filth>, 'Dusk…and Her Embrace'),
#  (<Band: Craft>, 'Terror Propaganda'),
#  (<Band: Cultes des Ghoules>, 'Cultes des Ghoules'),
#  (<Band: Dark Forest>, 'Aurora Borealis'),
#  (<Band: Dark Fortress>, 'Séance'),
#  (<Band: Dawn>, 'Slaughtersun (Crown of the Triarchy)'),
#  (<Band: Dawn>, 'Nær sólen gar niþer for evogher'),
#  (<Band: Desaster>, "Hellfire's Dominion"),
#  (<Band: Deströyer 666>, 'Cold Steel… for an Iron Age'),
#  (<Band: Diabolical Masquerade>, "Death's Design"),
#  (<Band: Dimmu Borgir>, 'Entrhone Darkness Triumphant'),
#  (<Band: Dissection>, "Storm of the Light's Bane"),
#  (<Band: Dissection>, 'The Somberlain'),
#  (<Band: Emperor>, 'In the Nightside Eclipse'),
#  (<Band: Emperor>, 'Anthems to the Welkin at Dusk'),
#  (<Band: Emperor>, 'Prometheus: The Discipline of Fire & Demise'),
#  (<Band: Emperor>, 'IX Equilibrium'),
#  (<Band: Enslaved>, 'Below the Lights'),
#  (<Band: Enslaved>, 'Vikingligr veldi'),
#  (<Band: Enslaved>, 'Isa'),
#  (<Band: Enslaved>, 'Ruun'),
#  (<Band: Enslaved>, 'Frost'),
#  (<Band: Enslaved>, 'Eld'),
#  (<Band: Enslaved>, 'Mardraum: Beyond the Within'),
#  (<Band: Enslaved>, 'Monumension'),
#  (<Band: Enslaved>, 'Blodhemn'),
#  (<Band: Entropia>, 'Vacuum'),
#  (<Band: Falkenbach>, 'Heralding: The Fireblade'),
#  (<Band: Farsot>, '…En Their Medh Riki Fara…'),
#  (<Band: Forgotten Tomb>, 'Songs to Leave'),
#  (<Band: Forgotten Tomb>, 'Springtime Depression'),
#  (<Band: Funeral Mist>, 'Salvation'),
#  (<Band: Funeral Mist>, 'Marantha'),
#  (<Band: Furia>, 'Martwa polska jesień'),
#  (<Band: Furia>, 'Nocel'),
#  (<Band: Furia>, 'Księżyc milczy luty'),
#  (<Band: Furia>, 'Grudzień za grudniem'),
#  (<Band: Gris>, "À l'âme enflammée, l'âme constellée..."),
#  (<Band: Hades>, 'The Dawn of the Dying Sun'),
#  (<Band: Hades>, '…Again Shall Be'),
#  (<Band: Immortal>, 'At the Heart of Winter'),
#  (<Band: Immortal>, 'Pure Holocaust'),
#  (<Band: Immortal>, 'Sons of Northern Darkness'),
#  (<Band: Immortal>, 'Battles in the North'),
#  ('In the Woods…', ''),
#  (<Band: Infernal War>,
#   'Redeskration: The Gospel of Hatred and Apotheosis of Genocide'),
#  (<Band: Inquisition>,
#   'Ominous Doctrones of the Perpetual Mystical Macrocosm'),
#  (<Band: Inquisition>, 'Invoking the Majestic Throne of Satan'),
#  (<Band: Inquisition>, 'Into the Infernal Regions of the Ancient Cult'),
#  (<Band: Inquisition>, 'Obscure Verses for the Multiverse'),
#  (<Band: Inquisition>, 'Magnificent Glorifiation of Lucifer'),
#  (<Band: Inquisition>, 'Nefarious Dismal Orations'),
#  (<Band: Katharsis>, 'Vvorldvvithoutend'),
#  (<Band: Katharsis>, 'Kruzifixxion'),
#  (<Band: Kawir>, 'Isotheos'),
#  ('Kvelertak', ''),
#  (<Band: Leviathan>, 'Massive Conspiracy Against All Life'),
#  (<Band: Leviathan>, 'The Tenth Sub Level of Suicide'),
#  (<Band: Leviathan>, 'Scar Sighted'),
#  (<Band: Leviathan>, 'Tentacles of Whorror'),
#  (<Band: Liturgy>, 'H.A.Q.Q.'),
#  ('Make a Change…Kill Yourself', ''),
#  ('Malkarpatan', ''),
#  (<Band: Marduk>, 'Those of the Unlight'),
#  (<Band: Marduk>, 'Opus Nocturne'),
#  (<Band: Marduk>, 'Rom 5:12'),
#  (<Band: Marduk>, 'Nightwing'),
#  (<Band: Mayhem>, 'De mysteriis dom Sathanas'),
#  (<Band: Mortuus>, 'De Contemplanda Morte'),
#  (<Band: Nagelfar>, 'Strontgorrth'),
#  (<Band: Naglfar>, 'Vittra'),
#  (<Band: Negură Bunget>, 'Măiestrit / Măiastru sfetnic'),
#  (<Band: Nifelheim>, 'Envoy of Lucifer'),
#  (<Band: Nifelheim>, 'Nifelheim'),
#  (<Band: Nifelheim>, 'Servants of Darkness'),
#  (<Band: Nocte Obducta>,
#   'Nektar - Teil I: Zwölf Monde, eine Hand voll Träume'),
#  (<Band: Odium>, 'The Sad Realm of the Stars'),
#  (<Band: Panopticon>, 'Autumn Eternal'),
#  (<Band: Panopticon>, 'Roads to the North'),
#  (<Band: Panopticon>, 'Kentucky'),
#  (<Band: Panzerfaust>, 'The Suns of Perdition - Chapter II: Render Unto Eden'),
#  (<Band: Paysage d'Hiver>, 'Winterkaelte'),
#  (<Band: Peste Noire>,
#   'La sanie des siècles : Panégyrique de la dégénérescence'),
#  (<Band: Revenge>, 'Behold Total Rejection'),
#  (<Band: Sadness>, 'I Want to Be There'),
#  (<Band: Samael>, 'Ceremony of Opposities'),
#  (<Band: Seth>, "Les blessures de l'âme"),
#  (<Band: Shining>, 'IV • The Eerie Cold'),
#  (<Band: Shining>, 'III - Angst - Självdestruktivitetens Emissarie'),
#  (<Band: Sigh>, "Hangman's Hymn"),
#  (<Band: Taake>, 'Nattestid ser porten vid…'),
#  (<Band: Taake>, '…Doedskvad'),
#  (<Band: Taake>, '…Bjoergvin…'),
#  (<Band: Tormentor>, 'Anno Domini'),
#  (<Band: Trist>, 'Stiny'),
#  (<Band: Trist>, 'Zrcadleni malencholie'),
#  (<Band: Ulver>, 'Bergtatt: Et eeventyr I 5 capitler'),
#  (<Band: Ulver>, 'Nattens madrigal: Aatte hymne til ulven I manden'),
#  (<Band: Vi>, 'De praestigiis angelorum'),
#  (<Band: Vemod>, 'Venter på stormene'),
#  (<Band: Xasthur>, 'To Violate the Oblivious'),
#  (<Band: Xasthur>, 'Telepathic With the Deceased'),
#  ('Батюшка\xa0[Batushka]', ''),
#  ('Крода\xa0[Kroda]', ''),
#  ('Лютомысл\xa0[Lutomysl]', ''),
#  ('מזמור\xa0[Mizmor]', '')]

# %%
black.assign(url='')
for row in urls:
    band, album, url = row
    band = band.name # accidentally used the Metallum result for the band here
    black.loc[(black['band'] == band) & (black['album'] == album), 'url'] = url

# %%
black
# Out:
#             band                                   album  \
# 0         Burzum                               Filosofem
# 1     Dissection               Storm of the Light's Bane
# 2        Emperor                In the Nightside Eclipse
# 3        Emperor           Anthems to the Welkin at Dusk
# 4          Ulver      Bergtatt: Et eeventyr I 5 capitler
# ..           ...                                     ...
# 501          møl                                    Jord
# 502  Mütiilation  Remains of a Ruined, Dead, Cursed Soul
# 503    Ravencult                            Morbid Blood
# 504   Forteresse                    Crépuscule d'octobre
# 505       Watain                        Lawless Darkness
#
#                                                    url
# 0    https://www.metal-archives.com/images/3/8/2/38...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 501                                                NaN
# 502  https://www.metal-archives.com/images/2/3/5/5/...
# 503  https://www.metal-archives.com/images/2/9/6/5/...
# 504  https://www.metal-archives.com/images/3/2/0/8/...
# 505  https://www.metal-archives.com/images/2/7/0/4/...
#
# [485 rows x 3 columns]

# %%
black.to_csv('black_urls.csv')

# %% [markdown]
# The missing URLs were found manually and fixed in the CSV. There were far more missing here, possibly because of the wider variety of punctuation and foreign characters, but more likely because there was some issue with the script

# %%
black = pd.read_csv('black_urls.csv', index_col=0)
black
# Out:
#             band                                   album  \
# 0         Burzum                               Filosofem
# 1     Dissection               Storm of the Light's Bane
# 2        Emperor                In the Nightside Eclipse
# 3        Emperor           Anthems to the Welkin at Dusk
# 4          Ulver      Bergtatt: Et eeventyr I 5 capitler
# ..           ...                                     ...
# 501          møl                                    Jord
# 502  Mütiilation  Remains of a Ruined, Dead, Cursed Soul
# 503    Ravencult                            Morbid Blood
# 504   Forteresse                    Crépuscule d'octobre
# 505       Watain                        Lawless Darkness
#
#                                                    url
# 0    https://www.metal-archives.com/images/3/8/2/38...
# 1    https://www.metal-archives.com/images/7/6/8/76...
# 2     https://www.metal-archives.com/images/9/3/93.jpg
# 3     https://www.metal-archives.com/images/9/2/92.jpg
# 4    https://www.metal-archives.com/images/3/6/0/9/...
# ..                                                 ...
# 501  https://www.metal-archives.com/images/6/9/4/1/...
# 502  https://www.metal-archives.com/images/2/3/5/5/...
# 503  https://www.metal-archives.com/images/2/9/6/5/...
# 504  https://www.metal-archives.com/images/3/2/0/8/...
# 505  https://www.metal-archives.com/images/2/7/0/4/...
#
# [485 rows x 3 columns]

# %%
black[black['url'].isnull()]
# Out:
#           band                      album  url
# 127  Kvelertak                  Kvelertak  NaN
# 257     Farsot  …En Their Medh Riki Fara…  NaN

# %% [markdown]
# There are some null values that I could not find with a manual search, so we will drop them

# %%
black = black.dropna()

# %%
for i, row in black.iterrows():
    band = row['band']
    url = row['url']
    img = f'{band}_{i}'
    download_cover(url, 'black', img)
